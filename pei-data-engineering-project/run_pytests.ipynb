# %%
import shutil

src = "/Workspace/Users/vikash110150@gmail.com/pei-data-engineering-project"
dst = "/tmp/pei-data-engineering-project"

shutil.copytree(src, dst, dirs_exist_ok=True)

# %%
# %sh
cp -r "/Workspace/Users/vikash110150@gmail.com/pei-data-engineering-project" /tmp/

# %%
# %sh
rm -rf /tmp/raw_test_data
mkdir -p /tmp/raw_test_data
cp "/Workspace/Users/vikash110150@gmail.com/raw_data/raw/Customer.xlsx" /tmp/raw_test_data/

# %%
import pytest

pytest.main([
    "/tmp/pei-data-engineering-project/tests",
    "-q"
])
